# %%
# install the newest version 
# !pip3 install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from pandas_profiling import ProfileReport

# %%
# will make plot outputs appear and stored within the notebook.
# %matplotlib inline

# %%
from google.colab import drive
# mount drive to access database
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
material_path = "/content/drive/MyDrive"

# %%
def connect_to_db(db_file):
    sqlite3_conn = None
    try:
        sqlite3_conn = sq.connect(db_file)
        return sqlite3_conn

    except Error as err:
        print(err)

        if sqlite3_conn is not None:
            sqlite3_conn.close()
  
dwh_conn = sqlite3.connect('/content/drive/MyDrive/DWH.db')

# %%
# list of tables in db
if dwh_conn is not None:
  dwh_cursor = dwh_conn.cursor()
  dwh_cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
  print("List of Tables", dwh_cursor.fetchall())
# Out:
# List of Tables [('Zentrum',), ('dimObservations',), ('dimEncounters',), ('dimProcedures',), ('dimConditions',), ('dimPatients',)]

# %% [markdown]
# Erstellen eines Ursprungsdataframes aus dem Datawarehouse

# %%
df = pd.read_sql_query("""
select dimEncounters.id as ENCOUNTER_ID, dimEncounters.start, dimEncounters.stop, dimEncounters.encounterclass, dimEncounters.code, dimEncounters.description,dimConditions.patient_id, dimConditions.code as DISEASE, dimConditions.description from dimConditions
left JOIN dimEncounters
on dimEncounters.id = dimConditions.encounter_id
;""", dwh_conn
)

# %%
df.head(6)
# Out:
#                            ENCOUNTER_ID  ...                                        DESCRIPTION
# 0  6e0279b7-c477-a2c6-e75c-a911f03a264c  ...  Perennial allergic rhinitis with seasonal vari...
# 1  40ca71e3-5668-dd3a-d7e1-209a43835384  ...            Body mass index 30+ - obesity (finding)
# 2  dbaad3dc-c5a8-9daf-5d5f-330a8022263f  ...            Body mass index 30+ - obesity (finding)
# 3  459c64dc-6783-3e8c-91d1-177c47c7258f  ...                                   Seizure disorder
# 4  459c64dc-6783-3e8c-91d1-177c47c7258f  ...              History of single seizure (situation)
# 5  be256df1-75cb-cbf7-0109-e0e1ae2c6348  ...                                       Hypertension
#
# [6 rows x 9 columns]

# %%
#Entfernen von Duplikaten
df.drop_duplicates(keep="first",inplace=True) 
print("Size of dataset after removing duplicated rows", df.shape)
# Out:
# Size of dataset after removing duplicated rows (9514, 9)

# %%
# Übersicht 
df.nunique(axis=0)
# Out:
# ENCOUNTER_ID      3446
# START             3400
# STOP              3417
# ENCOUNTERCLASS       6
# CODE                18
# DESCRIPTION         21
# PATIENT_ID        1947
# DISEASE            140
# DESCRIPTION        141
# dtype: int64

# %%
#Ursachen des Encounter
df.groupby(["DISEASE"]).size()
# Out:
# DISEASE
# 10509002           59
# 109838007          12
# 124171000119105     1
# 126906006           7
# 127013003           3
#                    ..
# 88805009            6
# 92691004            5
# 93761005            4
# 94260004            1
# 95417003            2
# Length: 140, dtype: int64

# %% [markdown]
# Erstellen eines Dataframes, der nur Angaben zu COVID-positiven Patienten enthält.

# %%
print(str(["DISEASE"]))
# Out:
# ['DISEASE']

# %%
DISEASE = map(int, "DISEASE")

# %%
#Selektion der enc Testergebnisse
dfencount = df.loc[(df["ENCOUNTERCLASS"] == "inpatient")]

# %%
dfencount.head(3)
# Out:
#                             ENCOUNTER_ID  ...              DESCRIPTION
# 11  e31a4c7a-a35c-0df1-60b2-b6c7ef012bce  ...  History of appendectomy
# 74  ccf7943f-b369-6ab8-b9e7-dafd2526804d  ...     Pneumonia (disorder)
# 75  ccf7943f-b369-6ab8-b9e7-dafd2526804d  ...     Hypoxemia (disorder)
#
# [3 rows x 9 columns]

# %%
#Selektion der positiven Testergebnisse
dfpos = df.loc[(df["DISEASE"] == "840544004") | (df["DISEASE"] == "840539006")]

# %%
print(dfpos.shape)
dfpos.head(20)
# Out:
# (1946, 9)
#                              ENCOUNTER_ID  ...         DESCRIPTION
# 30   3c7f472a-2602-bcdd-76d0-53f967923ded  ...  Suspected COVID-19
# 31   3c7f472a-2602-bcdd-76d0-53f967923ded  ...            COVID-19
# 42   dcee0f8b-907d-69cf-c998-5e73711f2276  ...  Suspected COVID-19
# 65   61c250a0-1668-e4ce-aefc-77a7842574c2  ...  Suspected COVID-19
# 66   61c250a0-1668-e4ce-aefc-77a7842574c2  ...            COVID-19
# 72   58a7a1b7-df6d-9bad-d58d-72bd4fe627cd  ...  Suspected COVID-19
# 73   58a7a1b7-df6d-9bad-d58d-72bd4fe627cd  ...            COVID-19
# 84   28b87b45-d287-5e9d-6a3d-c2e83ab9662e  ...  Suspected COVID-19
# 85   28b87b45-d287-5e9d-6a3d-c2e83ab9662e  ...            COVID-19
# 96   fbe97c06-afa3-050c-9a70-2523051b3bff  ...  Suspected COVID-19
# 97   fbe97c06-afa3-050c-9a70-2523051b3bff  ...            COVID-19
# 107  ea323bee-bfc1-5013-ba2b-8a11e38e7e2f  ...  Suspected COVID-19
# 108  ea323bee-bfc1-5013-ba2b-8a11e38e7e2f  ...            COVID-19
# 113  1fcea721-90cb-fc34-45bb-af1c092b24c6  ...  Suspected COVID-19
# 114  1fcea721-90cb-fc34-45bb-af1c092b24c6  ...            COVID-19
# 124  6c4a2d80-8ee8-0eae-1a86-e70f9ab3dac5  ...  Suspected COVID-19
# 125  6c4a2d80-8ee8-0eae-1a86-e70f9ab3dac5  ...            COVID-19
# 132  267554ba-dc87-0407-5abf-c4d5941ba1ed  ...  Suspected COVID-19
# 133  267554ba-dc87-0407-5abf-c4d5941ba1ed  ...            COVID-19
# 145  d8d738f4-afba-6809-1378-3db4e5ecf549  ...  Suspected COVID-19
#
# [20 rows x 9 columns]

# %%
dfpos.groupby(["ENCOUNTERCLASS"]).size()
# Out:
# ENCOUNTERCLASS
# ambulatory    1946
# dtype: int64

# %%
#Selektion der positiven Testergebnisse+stationärer Aufenthalt--> nicht vorhanden deswegen kein weitere Auswertung möglich
dfposin = df.loc[(df["DISEASE"] == "840544004") & (df["ENCOUNTERCLASS"] == "inpatient")| (df["DISEASE"] == "840539006") & (df["ENCOUNTERCLASS"] == "inpatient")]

# %%
print(dfposin.shape)
dfposin.head(6)
# Out:
# (0, 9)
# Empty DataFrame
# Columns: [ENCOUNTER_ID, START, STOP, ENCOUNTERCLASS, CODE, DESCRIPTION, PATIENT_ID, DISEASE, DESCRIPTION]
# Index: []
